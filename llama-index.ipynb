# %%
from llama_index.core import VectorStoreIndex, SimpleDirectoryReader
from dotenv import load_dotenv
# Out:
# False

# %%
load_dotenv()
# Out:
# True

# %%
documents = SimpleDirectoryReader("data").load_data()

# %%
documents
# Out:
# [Document(id_='7403b3e2-a66b-46c9-a1b6-8754fb0a71d8', embedding=None, metadata={'page_label': '1', 'file_name': '0583I-1210EN Pro.5 Alarm List.pdf', 'file_path': '/home/gops/work/maunal_gpt/data/0583I-1210EN Pro.5 Alarm List.pdf', 'file_type': 'application/pdf', 'file_size': 5880682, 'creation_date': '2024-10-27', 'last_modified_date': '2024-10-27'}, excluded_embed_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], excluded_llm_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], relationships={}, text='PROFESSIONAL 5\nALARM LIST\nApplicable Models\nAll Models\nNo.0583I-1210EN', mimetype='text/plain', start_char_idx=None, end_char_idx=None, text_template='{metadata_str}\n\n{content}', metadata_template='{key}: {value}', metadata_seperator='\n'),
# ...

# %%
index = VectorStoreIndex.from_documents(documents)

# %%
PERSIST_DIR = "./storage"

# %%
index.storage_context.persist(persist_dir=PERSIST_DIR)

# %%
query_engine = index.as_query_engine()

# %%
response = query_engine.query("HOW TO MANIPULATE pROGRAMS IN nc MEMORY")
# Out:
# To manipulate programs in NC memory, you can create new NC programs by changing the operation mode to edit mode, entering a program number in the program input area, and pressing the INSERT key. If the program number does not already exist in the NC memory, a new program will be created. Additionally, you can delete programs by selecting the program(s) to be deleted from the Program List Screen and then pressing the [Delete] screen operation button. This will prompt a Confirm Delete dialog box where you can choose to delete or cancel the deletion of the selected program(s).

# %%
print(response)
# Out:
# To manipulate programs in NC memory, you can create new NC programs by changing the operation mode to edit mode, entering a program number in the program input area, and pressing the INSERT key. If the program number does not already exist in the NC memory, a new program will be created. Additionally, you can delete programs by selecting the program(s) to be deleted from the Program List Screen and then pressing the [Delete] screen operation button. This will prompt a Confirm Delete dialog box where you can choose to delete or cancel the deletion of the selected program(s).

# %%
import gradio as gr

# %%
query_engine.query('how to change background')
# Out:
# Response(response='Press the [BG Edit] screen operation button to activate the BG Edit mode, allowing two programs to be simultaneously edited. To end the BG Edit mode, press the [BG Edit] screen operation button again.', source_nodes=[NodeWithScore(node=TextNode(id_='c56066a3-93c9-4b9a-bede-5dc8f70744ae', embedding=None, metadata={'page_label': '74', 'file_name': '638A-0503E Pro.5 Operation Manual Screen Edition.pdf', 'file_path': '/home/gops/work/maunal_gpt/data/638A-0503E Pro.5 Operation Manual Screen Edition.pdf', 'file_type': 'application/pdf', 'file_size': 4719087, 'creation_date': '2024-10-27', 'last_modified_date': '2024-10-27'}, excluded_embed_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], excluded_llm_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], relationships={<NodeRelationship.SOURCE: '1'>: RelatedNodeInfo(node_id='63630b70-8360-4d88-9
# ...

# %%
query_engine.query(message)

# %%
ask_llama('how to change background')
# Out:
# To manipulate programs in NC memory, you can create new NC programs by changing the operation mode to edit mode, entering a program number in the program input area, and pressing the INSERT key. If the program number does not already exist in the NC memory, a new program will be created. To delete programs from the program list, you need to select the program(s) to be deleted on the Program List Screen and then press the [Delete] screen operation button. This will prompt a Confirm Delete dialog box where you can press the [Yes] button to delete the selected program(s).

# %%
def ask_llama(message,memory):

    response = query_engine.query(message)
    return print(response)

# %%
gr.ChatInterface(fn=ask_llama).launch()
# Out:
# /home/gops/.local/lib/python3.10/site-packages/gradio/components/chatbot.py:229: UserWarning: The 'tuples' format for chatbot messages is deprecated and will be removed in a future version of Gradio. Please set type='messages' instead, which uses openai-style 'role' and 'content' keys.
#   warnings.warn(
# * Running on local URL:  http://127.0.0.1:7867
#
# To create a public link, set `share=True` in `launch()`.
# <div><iframe src="http://127.0.0.1:7867/" width="100%" height="500" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>
# I cannot provide an answer as the query is not clear. Please provide more specific information or a detailed question for me to assist you.
# Press the [BG Edit] screen operation button to activate the BG Edit mode, allowing two programs to be edited simultaneously.

# %%
gr.ChatInterface(
    ask_llama,
    type="messages",
    chatbot=gr.Chatbot(height=300),
    # textbox=gr.Textbox(placeholder="Ask me a yes or no question", container=False, scale=7),
    title="Manual Gpt",
    description="demo chatbot",
    theme="soft",
    # examples=[{"text": "Hello"}, {"text": "Am I cool?"}, {"text": "Are tomatoes vegetables?"}],
    cache_examples=True,

).launch()
# Out:
# /home/gops/.local/lib/python3.10/site-packages/gradio/components/chatbot.py:223: UserWarning: You have not specified a value for the `type` parameter. Defaulting to the 'tuples' format for chatbot messages, but this is deprecated and will be removed in a future version of Gradio. Please set type='messages' instead, which uses openai-style 'role' and 'content' keys.
#   warnings.warn(
# /home/gops/.local/lib/python3.10/site-packages/gradio/chat_interface.py:220: UserWarning: The type of the chatbot does not match the type of the chat interface. The type of the chat interface will be used.Recieved type of chatbot: {chatbot.type}, type of chat interface: {self.type}
#   warnings.warn(
# * Running on local URL:  http://127.0.0.1:7868
#
# To create a public link, set `share=True` in `launch()`.
# <div><iframe src="http://127.0.0.1:7868/" width="100%" height="500" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>
# ...
